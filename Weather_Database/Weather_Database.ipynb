# %% [markdown]
# ## Deliverable 1. Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %% [markdown]
# ## Generate Random Coordinates of World Cities

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Pack the latitudes (lats) and longitudes (lngs) as pairs by zipping them
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list - unpack zip object into a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descr = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_descr})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | belyy yar
# Processing Record 7 of Set 1 | carnarvon
# Processing Record 8 of Set 1 | georgetown
# Processing Record 9 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 1 | port hardy
# Processing Record 11 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 1 | vanavara
# Processing Record 13 of Set 1 | arraial do cabo
# Processing Record 14 of Set 1 | vostok
# Processing Record 15 of Set 1 | vila franca do campo
# Processing Record 16 of Set 1 | longyearbyen
# Processing Record 17 of Set 1 | pevek
# Processing Record 18 of Set 1 | phrai bung
# City not found. Skipping...
# Processing Record 19 of Set 1 | grootfontein
# Processing Record 20 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | tuatapere
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | ribeira grande
# Processing Record 26 of Set 1 | terenos
# Processing Record 27 of Set 1 | lima duarte
# Processing Record 28 of Set 1 | kharitonovo
# Processing Record 29 of Set 1 | college
# Processing Record 30 of Set 1 | nanortalik
# Processing Record 31 of Set 1 | kapaa
# Processing Record 32 of Set 1 | najran
# Processing Record 33 of Set 1 | tabou
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | defiance
# Processing Record 36 of Set 1 | nipawin
# Processing Record 37 of Set 1 | bethel
# Processing Record 38 of Set 1 | tondano
# Processing Record 39 of Set 1 | puerto ayora
# Processing Record 40 of Set 1 | ifakara
# Processing Record 41 of Set 1 | hobart
# Processing Record 42 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 1 | sinnamary
# Processing Record 44 of Set 1 | araguatins
# City not found. Skipping...
# Processing Record 45 of Set 1 | boca do acre
# Processing Record 46 of Set 1 | airai
# Processing Record 47 of Set 1 | saskylakh
# Processing Record 48 of Set 1 | coquimbo
# Processing Record 49 of Set 1 | xichang
# Processing Record 50 of Set 1 | provideniya
# Processing Record 1 of Set 2 | atuona
# Processing Record 2 of Set 2 | thompson
# Processing Record 3 of Set 2 | faanui
# Processing Record 4 of Set 2 | ponta do sol
# Processing Record 5 of Set 2 | fortuna
# Processing Record 6 of Set 2 | ostrovnoy
# Processing Record 7 of Set 2 | atasu
# Processing Record 8 of Set 2 | zhuhai
# Processing Record 9 of Set 2 | kodiak
# Processing Record 10 of Set 2 | lokoja
# Processing Record 11 of Set 2 | sanmenxia
# Processing Record 12 of Set 2 | eirunepe
# Processing Record 13 of Set 2 | chuy
# Processing Record 14 of Set 2 | saint-pierre
# Processing Record 15 of Set 2 | westport
# Processing Record 16 of Set 2 | chokurdakh
# Processing Record 17 of Set 2 | amahai
# Processing Record 18 of Set 2 | vilyuysk
# Processing Record 19 of Set 2 | puri
# Processing Record 20 of Set 2 | murray bridge
# Processing Record 21 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 2 | mar del plata
# Processing Record 23 of Set 2 | saint george
# Processing Record 24 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 2 | constitucion
# Processing Record 27 of Set 2 | khajuraho
# Processing Record 28 of Set 2 | kedougou
# Processing Record 29 of Set 2 | panaba
# Processing Record 30 of Set 2 | castro
# Processing Record 31 of Set 2 | bonthe
# Processing Record 32 of Set 2 | vaini
# Processing Record 33 of Set 2 | esperance
# Processing Record 34 of Set 2 | hilo
# Processing Record 35 of Set 2 | malpe
# Processing Record 36 of Set 2 | iqaluit
# Processing Record 37 of Set 2 | punta arenas
# Processing Record 38 of Set 2 | husainabad
# Processing Record 39 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 2 | bubaque
# Processing Record 41 of Set 2 | oistins
# Processing Record 42 of Set 2 | qaanaaq
# Processing Record 43 of Set 2 | hithadhoo
# Processing Record 44 of Set 2 | east london
# Processing Record 45 of Set 2 | tevaitoa
# Processing Record 46 of Set 2 | huntingdon
# Processing Record 47 of Set 2 | capreol
# Processing Record 48 of Set 2 | padang
# Processing Record 49 of Set 2 | sibolga
# Processing Record 50 of Set 2 | marquette
# Processing Record 1 of Set 3 | pisco
# Processing Record 2 of Set 3 | kochki
# Processing Record 3 of Set 3 | tuktoyaktuk
# Processing Record 4 of Set 3 | vestmannaeyjar
# Processing Record 5 of Set 3 | klaksvik
# Processing Record 6 of Set 3 | faya
# Processing Record 7 of Set 3 | muros
# Processing Record 8 of Set 3 | tasiilaq
# Processing Record 9 of Set 3 | ulmu
# Processing Record 10 of Set 3 | hammerfest
# Processing Record 11 of Set 3 | anito
# Processing Record 12 of Set 3 | khatanga
# Processing Record 13 of Set 3 | alausi
# Processing Record 14 of Set 3 | inhambane
# Processing Record 15 of Set 3 | maceio
# Processing Record 16 of Set 3 | kirya
# Processing Record 17 of Set 3 | kamenka
# Processing Record 18 of Set 3 | new norfolk
# Processing Record 19 of Set 3 | muana
# Processing Record 20 of Set 3 | sioux lookout
# Processing Record 21 of Set 3 | mogadishu
# Processing Record 22 of Set 3 | taksimo
# Processing Record 23 of Set 3 | muzhi
# Processing Record 24 of Set 3 | ndago
# Processing Record 25 of Set 3 | huarmey
# Processing Record 26 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 3 | erzincan
# Processing Record 28 of Set 3 | buraydah
# Processing Record 29 of Set 3 | ilebo
# Processing Record 30 of Set 3 | hualmay
# Processing Record 31 of Set 3 | lashio
# Processing Record 32 of Set 3 | sambava
# Processing Record 33 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 34 of Set 3 | nikolskoye
# Processing Record 35 of Set 3 | dalvik
# Processing Record 36 of Set 3 | bahia honda
# Processing Record 37 of Set 3 | yurla
# Processing Record 38 of Set 3 | mao
# Processing Record 39 of Set 3 | puerto escondido
# Processing Record 40 of Set 3 | lincoln
# Processing Record 41 of Set 3 | rio cuarto
# Processing Record 42 of Set 3 | norman wells
# Processing Record 43 of Set 3 | butaritari
# Processing Record 44 of Set 3 | bengkulu
# Processing Record 45 of Set 3 | sakharovo
# Processing Record 46 of Set 3 | cherskiy
# Processing Record 47 of Set 3 | shache
# Processing Record 48 of Set 3 | alamosa
# Processing Record 49 of Set 3 | dikson
# Processing Record 50 of Set 3 | matagami
# Processing Record 1 of Set 4 | kaitangata
# Processing Record 2 of Set 4 | guerrero negro
# Processing Record 3 of Set 4 | grindavik
# Processing Record 4 of Set 4 | berdigestyakh
# Processing Record 5 of Set 4 | rio grande
# Processing Record 6 of Set 4 | muroto
# Processing Record 7 of Set 4 | odessa
# Processing Record 8 of Set 4 | saint-joseph
# Processing Record 9 of Set 4 | san patricio
# Processing Record 10 of Set 4 | uppsala
# Processing Record 11 of Set 4 | bredasdorp
# Processing Record 12 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 4 | ust-tsilma
# Processing Record 14 of Set 4 | saint-philippe
# Processing Record 15 of Set 4 | aborlan
# Processing Record 16 of Set 4 | san cristobal
# Processing Record 17 of Set 4 | hambantota
# Processing Record 18 of Set 4 | carballo
# Processing Record 19 of Set 4 | akureyri
# Processing Record 20 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 4 | pacific grove
# Processing Record 23 of Set 4 | rawson
# Processing Record 24 of Set 4 | yerbogachen
# Processing Record 25 of Set 4 | aklavik
# Processing Record 26 of Set 4 | cabo san lucas
# Processing Record 27 of Set 4 | hofn
# Processing Record 28 of Set 4 | baiyin
# Processing Record 29 of Set 4 | tulagi
# Processing Record 30 of Set 4 | bandarbeyla
# Processing Record 31 of Set 4 | mahadday weyne
# City not found. Skipping...
# Processing Record 32 of Set 4 | narsaq
# Processing Record 33 of Set 4 | lebu
# Processing Record 34 of Set 4 | moree
# Processing Record 35 of Set 4 | san juan de la maguana
# Processing Record 36 of Set 4 | sobolevo
# Processing Record 37 of Set 4 | cape town
# Processing Record 38 of Set 4 | tjome
# Processing Record 39 of Set 4 | lorengau
# Processing Record 40 of Set 4 | koroni
# Processing Record 41 of Set 4 | iquique
# Processing Record 42 of Set 4 | karratha
# Processing Record 43 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 4 | murud
# Processing Record 45 of Set 4 | victoria
# Processing Record 46 of Set 4 | galle
# Processing Record 47 of Set 4 | mehamn
# Processing Record 48 of Set 4 | axim
# Processing Record 49 of Set 4 | matay
# Processing Record 50 of Set 4 | kamenz
# Processing Record 1 of Set 5 | bathsheba
# Processing Record 2 of Set 5 | oktyabrskiy
# Processing Record 3 of Set 5 | kununurra
# Processing Record 4 of Set 5 | saint-ambroise
# Processing Record 5 of Set 5 | quelimane
# Processing Record 6 of Set 5 | miandrivazo
# Processing Record 7 of Set 5 | mersing
# Processing Record 8 of Set 5 | kangaatsiaq
# Processing Record 9 of Set 5 | nishihara
# Processing Record 10 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 5 | kashi
# Processing Record 12 of Set 5 | te anau
# Processing Record 13 of Set 5 | tual
# Processing Record 14 of Set 5 | ambilobe
# Processing Record 15 of Set 5 | bedford
# Processing Record 16 of Set 5 | dunedin
# Processing Record 17 of Set 5 | ambulu
# Processing Record 18 of Set 5 | cayenne
# Processing Record 19 of Set 5 | husavik
# Processing Record 20 of Set 5 | acari
# Processing Record 21 of Set 5 | garden city
# Processing Record 22 of Set 5 | orito
# Processing Record 23 of Set 5 | nhulunbuy
# Processing Record 24 of Set 5 | half moon bay
# Processing Record 25 of Set 5 | taltal
# Processing Record 26 of Set 5 | kismayo
# Processing Record 27 of Set 5 | erenhot
# Processing Record 28 of Set 5 | hay river
# Processing Record 29 of Set 5 | urubicha
# Processing Record 30 of Set 5 | sakhon nakhon
# Processing Record 31 of Set 5 | galchino
# City not found. Skipping...
# Processing Record 32 of Set 5 | amapa
# Processing Record 33 of Set 5 | kaeo
# Processing Record 34 of Set 5 | tambacounda
# Processing Record 35 of Set 5 | lagoa
# Processing Record 36 of Set 5 | marand
# Processing Record 37 of Set 5 | lacarak
# Processing Record 38 of Set 5 | sao filipe
# Processing Record 39 of Set 5 | richards bay
# Processing Record 40 of Set 5 | brae
# Processing Record 41 of Set 5 | hargeysa
# Processing Record 42 of Set 5 | aykhal
# Processing Record 43 of Set 5 | namibe
# Processing Record 44 of Set 5 | taywarah
# Processing Record 45 of Set 5 | sawtell
# Processing Record 46 of Set 5 | songjianghe
# Processing Record 47 of Set 5 | sibiti
# Processing Record 48 of Set 5 | hue
# Processing Record 49 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 50 of Set 5 | leshukonskoye
# Processing Record 1 of Set 6 | makat
# Processing Record 2 of Set 6 | henderson
# Processing Record 3 of Set 6 | santa lucia
# Processing Record 4 of Set 6 | komsomolets
# Processing Record 5 of Set 6 | upernavik
# Processing Record 6 of Set 6 | barrow
# Processing Record 7 of Set 6 | margate
# Processing Record 8 of Set 6 | griffith
# Processing Record 9 of Set 6 | myitkyina
# Processing Record 10 of Set 6 | finschhafen
# Processing Record 11 of Set 6 | poladpur
# Processing Record 12 of Set 6 | port elizabeth
# Processing Record 13 of Set 6 | quesnel
# Processing Record 14 of Set 6 | walvis bay
# Processing Record 15 of Set 6 | ballangen
# Processing Record 16 of Set 6 | palmer
# Processing Record 17 of Set 6 | lazarev
# Processing Record 18 of Set 6 | khilok
# Processing Record 19 of Set 6 | the valley
# Processing Record 20 of Set 6 | ilulissat
# Processing Record 21 of Set 6 | qiongshan
# Processing Record 22 of Set 6 | umm lajj
# Processing Record 23 of Set 6 | montagnana
# Processing Record 24 of Set 6 | gat
# Processing Record 25 of Set 6 | biak
# Processing Record 26 of Set 6 | lasa
# Processing Record 27 of Set 6 | port lincoln
# Processing Record 28 of Set 6 | ranong
# Processing Record 29 of Set 6 | shelburne
# Processing Record 30 of Set 6 | lidkoping
# Processing Record 31 of Set 6 | miri
# Processing Record 32 of Set 6 | ponta delgada
# Processing Record 33 of Set 6 | kawalu
# Processing Record 34 of Set 6 | sorong
# Processing Record 35 of Set 6 | aksarka
# Processing Record 36 of Set 6 | isiro
# Processing Record 37 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 6 | olinda
# Processing Record 39 of Set 6 | lima
# Processing Record 40 of Set 6 | manokwari
# Processing Record 41 of Set 6 | havre-saint-pierre
# Processing Record 42 of Set 6 | hasaki
# Processing Record 43 of Set 6 | shetpe
# Processing Record 44 of Set 6 | tuy hoa
# Processing Record 45 of Set 6 | kabare
# Processing Record 46 of Set 6 | rafai
# Processing Record 47 of Set 6 | srednekolymsk
# Processing Record 48 of Set 6 | souillac
# Processing Record 49 of Set 6 | corrales
# Processing Record 50 of Set 6 | tiksi
# Processing Record 1 of Set 7 | druzhba
# Processing Record 2 of Set 7 | fairbanks
# Processing Record 3 of Set 7 | port angeles
# Processing Record 4 of Set 7 | sitka
# Processing Record 5 of Set 7 | lastoursville
# Processing Record 6 of Set 7 | simao
# Processing Record 7 of Set 7 | kargil
# Processing Record 8 of Set 7 | inuvik
# Processing Record 9 of Set 7 | matara
# Processing Record 10 of Set 7 | henties bay
# Processing Record 11 of Set 7 | berlevag
# Processing Record 12 of Set 7 | zeya
# Processing Record 13 of Set 7 | templemore
# Processing Record 14 of Set 7 | samur
# Processing Record 15 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 16 of Set 7 | mazara del vallo
# Processing Record 17 of Set 7 | puerto suarez
# Processing Record 18 of Set 7 | okrika
# Processing Record 19 of Set 7 | kralendijk
# Processing Record 20 of Set 7 | salinopolis
# Processing Record 21 of Set 7 | mahebourg
# Processing Record 22 of Set 7 | leningradskiy
# Processing Record 23 of Set 7 | sept-iles
# Processing Record 24 of Set 7 | nsanje
# Processing Record 25 of Set 7 | severo-kurilsk
# Processing Record 26 of Set 7 | waingapu
# Processing Record 27 of Set 7 | kieta
# Processing Record 28 of Set 7 | sur
# Processing Record 29 of Set 7 | kahului
# Processing Record 30 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 32 of Set 7 | dryden
# Processing Record 33 of Set 7 | cidreira
# Processing Record 34 of Set 7 | lompoc
# Processing Record 35 of Set 7 | yangambi
# Processing Record 36 of Set 7 | ridgecrest
# Processing Record 37 of Set 7 | yinchuan
# Processing Record 38 of Set 7 | marawi
# Processing Record 39 of Set 7 | hami
# Processing Record 40 of Set 7 | lancaster
# Processing Record 41 of Set 7 | kalabo
# Processing Record 42 of Set 7 | big rapids
# Processing Record 43 of Set 7 | necochea
# Processing Record 44 of Set 7 | ahipara
# Processing Record 45 of Set 7 | kemin
# Processing Record 46 of Set 7 | aurdal
# Processing Record 47 of Set 7 | bambous virieux
# Processing Record 48 of Set 7 | haines junction
# Processing Record 49 of Set 7 | salto
# Processing Record 50 of Set 7 | spearfish
# Processing Record 1 of Set 8 | hailar
# Processing Record 2 of Set 8 | altea
# Processing Record 3 of Set 8 | kungurtug
# Processing Record 4 of Set 8 | balad
# Processing Record 5 of Set 8 | dong hoi
# Processing Record 6 of Set 8 | tautira
# Processing Record 7 of Set 8 | partizanskoye
# Processing Record 8 of Set 8 | ndjole
# Processing Record 9 of Set 8 | birao
# Processing Record 10 of Set 8 | vao
# Processing Record 11 of Set 8 | rajula
# Processing Record 12 of Set 8 | komsomolskiy
# Processing Record 13 of Set 8 | korvekula
# City not found. Skipping...
# Processing Record 14 of Set 8 | tura
# Processing Record 15 of Set 8 | guntur
# Processing Record 16 of Set 8 | alofi
# Processing Record 17 of Set 8 | puerto madryn
# Processing Record 18 of Set 8 | poronaysk
# Processing Record 19 of Set 8 | luwingu
# Processing Record 20 of Set 8 | trinidad
# Processing Record 21 of Set 8 | stephenville
# Processing Record 22 of Set 8 | kirakira
# Processing Record 23 of Set 8 | gangiova
# Processing Record 24 of Set 8 | callaway
# Processing Record 25 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 26 of Set 8 | bousse
# Processing Record 27 of Set 8 | emirdag
# Processing Record 28 of Set 8 | mahanoro
# Processing Record 29 of Set 8 | katobu
# Processing Record 30 of Set 8 | kruisfontein
# Processing Record 31 of Set 8 | riyadh
# Processing Record 32 of Set 8 | dhidhdhoo
# Processing Record 33 of Set 8 | avarua
# Processing Record 34 of Set 8 | dukat
# Processing Record 35 of Set 8 | praesto
# Processing Record 36 of Set 8 | gimbi
# Processing Record 37 of Set 8 | locri
# Processing Record 38 of Set 8 | dolores
# Processing Record 39 of Set 8 | mahibadhoo
# Processing Record 40 of Set 8 | acarau
# Processing Record 41 of Set 8 | bardsir
# Processing Record 42 of Set 8 | chilca
# Processing Record 43 of Set 8 | sombrio
# Processing Record 44 of Set 8 | kenai
# Processing Record 45 of Set 8 | talawdi
# City not found. Skipping...
# Processing Record 46 of Set 8 | tunduru
# City not found. Skipping...
# Processing Record 47 of Set 8 | katsuura
# Processing Record 48 of Set 8 | rahden
# Processing Record 49 of Set 8 | lubango
# Processing Record 50 of Set 8 | hoi an
# Processing Record 1 of Set 9 | sao joao da barra
# Processing Record 2 of Set 9 | yenagoa
# Processing Record 3 of Set 9 | bangkalan
# Processing Record 4 of Set 9 | burnie
# Processing Record 5 of Set 9 | gurskoye
# City not found. Skipping...
# Processing Record 6 of Set 9 | zhangye
# Processing Record 7 of Set 9 | kurilsk
# Processing Record 8 of Set 9 | gusau
# Processing Record 9 of Set 9 | broken hill
# Processing Record 10 of Set 9 | itarema
# Processing Record 11 of Set 9 | karasuk
# Processing Record 12 of Set 9 | belmonte
# Processing Record 13 of Set 9 | jieshi
# Processing Record 14 of Set 9 | sisimiut
# Processing Record 15 of Set 9 | udachnyy
# Processing Record 16 of Set 9 | kargopol
# Processing Record 17 of Set 9 | sao miguel do araguaia
# Processing Record 18 of Set 9 | lusambo
# Processing Record 19 of Set 9 | sembakung
# Processing Record 20 of Set 9 | ola
# Processing Record 21 of Set 9 | kahuta
# Processing Record 22 of Set 9 | gillette
# Processing Record 23 of Set 9 | iskateley
# Processing Record 24 of Set 9 | deputatskiy
# Processing Record 25 of Set 9 | rio gallegos
# Processing Record 26 of Set 9 | correderos
# Processing Record 27 of Set 9 | vredendal
# Processing Record 28 of Set 9 | amudat
# Processing Record 29 of Set 9 | sault sainte marie
# Processing Record 30 of Set 9 | labuhan
# Processing Record 31 of Set 9 | atbasar
# Processing Record 32 of Set 9 | yarmouth
# Processing Record 33 of Set 9 | kloulklubed
# Processing Record 34 of Set 9 | mecca
# Processing Record 35 of Set 9 | yellowknife
# Processing Record 36 of Set 9 | praia da vitoria
# Processing Record 37 of Set 9 | atakpame
# Processing Record 38 of Set 9 | bereda
# Processing Record 39 of Set 9 | pascagoula
# Processing Record 40 of Set 9 | torbay
# Processing Record 41 of Set 9 | wellington
# Processing Record 42 of Set 9 | xacmaz
# Processing Record 43 of Set 9 | lesnoy
# Processing Record 44 of Set 9 | nisia floresta
# Processing Record 45 of Set 9 | pangnirtung
# Processing Record 46 of Set 9 | tamandare
# Processing Record 47 of Set 9 | cuajinicuilapa
# Processing Record 48 of Set 9 | marabba
# Processing Record 49 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 9 | ancud
# Processing Record 1 of Set 10 | vardo
# Processing Record 2 of Set 10 | cockburn town
# Processing Record 3 of Set 10 | newport
# Processing Record 4 of Set 10 | caucaia
# Processing Record 5 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 10 | anloga
# Processing Record 7 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 8 of Set 10 | keetmanshoop
# Processing Record 9 of Set 10 | kargasok
# Processing Record 10 of Set 10 | oktyabrskoye
# Processing Record 11 of Set 10 | cordoba
# Processing Record 12 of Set 10 | banamba
# Processing Record 13 of Set 10 | portland
# Processing Record 14 of Set 10 | naze
# Processing Record 15 of Set 10 | santa barbara
# Processing Record 16 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 17 of Set 10 | mattru
# Processing Record 18 of Set 10 | luderitz
# Processing Record 19 of Set 10 | sindor
# Processing Record 20 of Set 10 | kamaishi
# Processing Record 21 of Set 10 | nioro
# Processing Record 22 of Set 10 | thiruvananthapuram
# Processing Record 23 of Set 10 | andrelandia
# Processing Record 24 of Set 10 | ukiah
# Processing Record 25 of Set 10 | calama
# Processing Record 26 of Set 10 | xapuri
# Processing Record 27 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 10 | hobyo
# Processing Record 29 of Set 10 | bulgan
# Processing Record 30 of Set 10 | nizhneangarsk
# Processing Record 31 of Set 10 | nelson bay
# Processing Record 32 of Set 10 | santa ana
# Processing Record 33 of Set 10 | eureka
# Processing Record 34 of Set 10 | tsabong
# Processing Record 35 of Set 10 | pangody
# Processing Record 36 of Set 10 | ust-omchug
# Processing Record 37 of Set 10 | strezhevoy
# Processing Record 38 of Set 10 | okhotsk
# Processing Record 39 of Set 10 | bozoum
# Processing Record 40 of Set 10 | leua
# Processing Record 41 of Set 10 | acapulco
# Processing Record 42 of Set 10 | cururupu
# Processing Record 43 of Set 10 | belaya gora
# Processing Record 44 of Set 10 | boddam
# Processing Record 45 of Set 10 | omaha
# Processing Record 46 of Set 10 | lyubim
# Processing Record 47 of Set 10 | gotsu
# Processing Record 48 of Set 10 | phangnga
# Processing Record 49 of Set 10 | sheridan
# Processing Record 50 of Set 10 | santa maria del oro
# Processing Record 1 of Set 11 | puerto colombia
# Processing Record 2 of Set 11 | codrington
# Processing Record 3 of Set 11 | nicoya
# Processing Record 4 of Set 11 | sangar
# Processing Record 5 of Set 11 | broome
# Processing Record 6 of Set 11 | namatanai
# Processing Record 7 of Set 11 | yashan
# Processing Record 8 of Set 11 | parry sound
# Processing Record 9 of Set 11 | mandera
# Processing Record 10 of Set 11 | mosta
# Processing Record 11 of Set 11 | caetite
# Processing Record 12 of Set 11 | koutsouras
# Processing Record 13 of Set 11 | chichester
# Processing Record 14 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 15 of Set 11 | flinders
# Processing Record 16 of Set 11 | myaundzha
# Processing Record 17 of Set 11 | long xuyen
# Processing Record 18 of Set 11 | batemans bay
# Processing Record 19 of Set 11 | tchamba
# Processing Record 20 of Set 11 | jinka
# Processing Record 21 of Set 11 | vila velha
# Processing Record 22 of Set 11 | huaihua
# Processing Record 23 of Set 11 | verkhoyansk
# Processing Record 24 of Set 11 | san nicolas
# Processing Record 25 of Set 11 | pinahat
# Processing Record 26 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 27 of Set 11 | peniche
# Processing Record 28 of Set 11 | akot
# Processing Record 29 of Set 11 | tirlyanskiy
# Processing Record 30 of Set 11 | porto velho
# Processing Record 31 of Set 11 | boyolangu
# Processing Record 32 of Set 11 | tan an
# Processing Record 33 of Set 11 | kodinsk
# Processing Record 34 of Set 11 | corinto
# Processing Record 35 of Set 11 | takoradi
# Processing Record 36 of Set 11 | karlshamn
# Processing Record 37 of Set 11 | qingdao
# Processing Record 38 of Set 11 | nouadhibou
# Processing Record 39 of Set 11 | chifeng
# Processing Record 40 of Set 11 | svetlaya
# Processing Record 41 of Set 11 | whitehorse
# Processing Record 42 of Set 11 | constantine
# Processing Record 43 of Set 11 | severo-yeniseyskiy
# Processing Record 44 of Set 11 | port hedland
# Processing Record 45 of Set 11 | dawlatabad
# Processing Record 46 of Set 11 | prince rupert
# Processing Record 47 of Set 11 | paraiso
# Processing Record 48 of Set 11 | soyo
# Processing Record 49 of Set 11 | banda aceh
# Processing Record 50 of Set 11 | yen bai
# Processing Record 1 of Set 12 | williams lake
# Processing Record 2 of Set 12 | vagamo
# Processing Record 3 of Set 12 | purpe
# Processing Record 4 of Set 12 | monrovia
# Processing Record 5 of Set 12 | ahuimanu
# Processing Record 6 of Set 12 | turukhansk
# Processing Record 7 of Set 12 | port-de-bouc
# Processing Record 8 of Set 12 | bonavista
# Processing Record 9 of Set 12 | chernitsyno
# Processing Record 10 of Set 12 | olafsvik
# Processing Record 11 of Set 12 | manta
# Processing Record 12 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 12 | semey
# Processing Record 14 of Set 12 | pierre
# Processing Record 15 of Set 12 | balkanabat
# Processing Record 16 of Set 12 | gravdal
# Processing Record 17 of Set 12 | jinxiang
# Processing Record 18 of Set 12 | khandyga
# Processing Record 19 of Set 12 | itaituba
# Processing Record 20 of Set 12 | ituni
# City not found. Skipping...
# Processing Record 21 of Set 12 | verkhnyaya toyma
# Processing Record 22 of Set 12 | vaitape
# Processing Record 23 of Set 12 | cody
# Processing Record 24 of Set 12 | zaozerne
# Processing Record 25 of Set 12 | mnogovershinnyy
# Processing Record 26 of Set 12 | chhapra
# Processing Record 27 of Set 12 | tazovskiy
# Processing Record 28 of Set 12 | kadiri
# Processing Record 29 of Set 12 | pankrushikha
# Processing Record 30 of Set 12 | rosetta
# Processing Record 31 of Set 12 | kabanjahe
# Processing Record 32 of Set 12 | santa vitoria do palmar
# Processing Record 33 of Set 12 | niteroi
# Processing Record 34 of Set 12 | voyvozh
# Processing Record 35 of Set 12 | saint-georges
# Processing Record 36 of Set 12 | chokwe
# Processing Record 37 of Set 12 | kudahuvadhoo
# Processing Record 38 of Set 12 | hostotipaquillo
# Processing Record 39 of Set 12 | raduzhnyy
# Processing Record 40 of Set 12 | salalah
# Processing Record 41 of Set 12 | banjar
# Processing Record 42 of Set 12 | salair
# Processing Record 43 of Set 12 | hiroshima
# Processing Record 44 of Set 12 | penzance
# Processing Record 45 of Set 12 | uruzgan
# Processing Record 46 of Set 12 | along
# Processing Record 47 of Set 12 | mercedes
# Processing Record 48 of Set 12 | alyangula
# Processing Record 49 of Set 12 | rabo de peixe
# Processing Record 50 of Set 12 | goundam
# Processing Record 1 of Set 13 | port shepstone
# Processing Record 2 of Set 13 | matamoros
# Processing Record 3 of Set 13 | oytal
# Processing Record 4 of Set 13 | chicama
# Processing Record 5 of Set 13 | cheuskiny
# City not found. Skipping...
# Processing Record 6 of Set 13 | la macarena
# Processing Record 7 of Set 13 | chatra
# Processing Record 8 of Set 13 | daru
# Processing Record 9 of Set 13 | sillod
# Processing Record 10 of Set 13 | podosinovets
# Processing Record 11 of Set 13 | bagdarin
# Processing Record 12 of Set 13 | businga
# Processing Record 13 of Set 13 | antofagasta
# Processing Record 14 of Set 13 | weiser
# Processing Record 15 of Set 13 | florianopolis
# Processing Record 16 of Set 13 | dudinka
# Processing Record 17 of Set 13 | bulawayo
# Processing Record 18 of Set 13 | beringovskiy
# Processing Record 19 of Set 13 | tocopilla
# Processing Record 20 of Set 13 | seoul
# Processing Record 21 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 22 of Set 13 | dubbo
# Processing Record 23 of Set 13 | bronnoysund
# Processing Record 24 of Set 13 | oblivskaya
# Processing Record 25 of Set 13 | thinadhoo
# Processing Record 26 of Set 13 | gimli
# Processing Record 27 of Set 13 | vilhena
# Processing Record 28 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 29 of Set 13 | ayagoz
# Processing Record 30 of Set 13 | benalla
# Processing Record 31 of Set 13 | obera
# Processing Record 32 of Set 13 | linjiang
# Processing Record 33 of Set 13 | ongandjera
# Processing Record 34 of Set 13 | santa maria
# Processing Record 35 of Set 13 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 36 of Set 13 | geraldton
# Processing Record 37 of Set 13 | tchaourou
# Processing Record 38 of Set 13 | enumclaw
# Processing Record 39 of Set 13 | the pas
# Processing Record 40 of Set 13 | zenzeli
# Processing Record 41 of Set 13 | ayer itam
# City not found. Skipping...
# Processing Record 42 of Set 13 | stornoway
# Processing Record 43 of Set 13 | sao jose da coroa grande
# Processing Record 44 of Set 13 | ambunti
# Processing Record 45 of Set 13 | drochia
# Processing Record 46 of Set 13 | sompeta
# Processing Record 47 of Set 13 | kambove
# Processing Record 48 of Set 13 | beidaud
# Processing Record 49 of Set 13 | maarianhamina
# Processing Record 50 of Set 13 | linqiong
# Processing Record 1 of Set 14 | lokosovo
# Processing Record 2 of Set 14 | gyomaendrod
# Processing Record 3 of Set 14 | tomaszow lubelski
# Processing Record 4 of Set 14 | oranjestad
# Processing Record 5 of Set 14 | barmer
# Processing Record 6 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 7 of Set 14 | kuytun
# Processing Record 8 of Set 14 | zorritos
# Processing Record 9 of Set 14 | clyde river
# Processing Record 10 of Set 14 | evensk
# Processing Record 11 of Set 14 | homer
# Processing Record 12 of Set 14 | jibuti
# Processing Record 13 of Set 14 | lavrentiya
# Processing Record 14 of Set 14 | cairns
# Processing Record 15 of Set 14 | vereshchagino
# Processing Record 16 of Set 14 | whitchurch-stouffville
# City not found. Skipping...
# Processing Record 17 of Set 14 | lata
# Processing Record 18 of Set 14 | brzesko
# Processing Record 19 of Set 14 | bozovici
# Processing Record 20 of Set 14 | gunjur
# Processing Record 21 of Set 14 | nome
# Processing Record 22 of Set 14 | paamiut
# Processing Record 23 of Set 14 | canchungo
# Processing Record 24 of Set 14 | terrace bay
# Processing Record 25 of Set 14 | jining
# Processing Record 26 of Set 14 | bunbury
# Processing Record 27 of Set 14 | kiama
# Processing Record 28 of Set 14 | talnakh
# Processing Record 29 of Set 14 | pereslavl-zalesskiy
# Processing Record 30 of Set 14 | waipawa
# Processing Record 31 of Set 14 | kiunga
# Processing Record 32 of Set 14 | praia
# Processing Record 33 of Set 14 | bredy
# Processing Record 34 of Set 14 | yar-sale
# Processing Record 35 of Set 14 | jabiru
# City not found. Skipping...
# Processing Record 36 of Set 14 | lagos
# Processing Record 37 of Set 14 | magole
# Processing Record 38 of Set 14 | qeshm
# Processing Record 39 of Set 14 | coihaique
# Processing Record 40 of Set 14 | bilibino
# Processing Record 41 of Set 14 | mogoytuy
# Processing Record 42 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 43 of Set 14 | caravelas
# Processing Record 44 of Set 14 | waddan
# Processing Record 45 of Set 14 | ibimirim
# Processing Record 46 of Set 14 | uvat
# Processing Record 47 of Set 14 | beshpagir
# Processing Record 48 of Set 14 | ostersund
# Processing Record 49 of Set 14 | demyansk
# Processing Record 50 of Set 14 | mount gambier
# Processing Record 1 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 2 of Set 15 | santa rosa
# Processing Record 3 of Set 15 | hamm
# Processing Record 4 of Set 15 | barvinkove
# Processing Record 5 of Set 15 | los llanos de aridane
# Processing Record 6 of Set 15 | omboue
# Processing Record 7 of Set 15 | mgachi
# Processing Record 8 of Set 15 | rocha
# Processing Record 9 of Set 15 | sayyan
# Processing Record 10 of Set 15 | safwah
# City not found. Skipping...
# Processing Record 11 of Set 15 | saint-francois
# Processing Record 12 of Set 15 | bueno brandao
# Processing Record 13 of Set 15 | la rioja
# Processing Record 14 of Set 15 | jijiga
# Processing Record 15 of Set 15 | mahasamund
# Processing Record 16 of Set 15 | hellin
# Processing Record 17 of Set 15 | thaba-tseka
# Processing Record 18 of Set 15 | monkey bay
# Processing Record 19 of Set 15 | sohag
# Processing Record 20 of Set 15 | cozumel
# Processing Record 21 of Set 15 | suntar
# Processing Record 22 of Set 15 | suzu
# City not found. Skipping...
# Processing Record 23 of Set 15 | vankleek hill
# Processing Record 24 of Set 15 | kerema
# Processing Record 25 of Set 15 | temir
# Processing Record 26 of Set 15 | batagay-alyta
# Processing Record 27 of Set 15 | roald
# Processing Record 28 of Set 15 | alice springs
# Processing Record 29 of Set 15 | kavaratti
# Processing Record 30 of Set 15 | tongchuan
# Processing Record 31 of Set 15 | port blair
# Processing Record 32 of Set 15 | tiznit
# Processing Record 33 of Set 15 | bled
# Processing Record 34 of Set 15 | la ronge
# Processing Record 35 of Set 15 | kavieng
# Processing Record 36 of Set 15 | karakol
# Processing Record 37 of Set 15 | anjozorobe
# Processing Record 38 of Set 15 | maningrida
# Processing Record 39 of Set 15 | giyon
# Processing Record 40 of Set 15 | saldanha
# Processing Record 41 of Set 15 | san carlos
# Processing Record 42 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 43 of Set 15 | wajima
# Processing Record 44 of Set 15 | leh
# Processing Record 45 of Set 15 | pervomayskoye
# Processing Record 46 of Set 15 | honningsvag
# Processing Record 47 of Set 15 | rudbar
# Processing Record 48 of Set 15 | guaruja
# Processing Record 49 of Set 15 | banyo
# Processing Record 50 of Set 15 | saint-augustin
# Processing Record 1 of Set 16 | trairi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Bluff      NZ -46.6000  168.3333     59.81        61          45
# 1     Mataura      NZ -46.1927  168.8643     59.49        40          11
# 2     Rikitea      PF -23.1203 -134.9692     78.76        71         100
# 3    Hermanus      ZA -34.4187   19.2345     84.90        62          49
# 4   Jamestown      US  42.0970  -79.2353     22.71        63         100
# 5   Belyy Yar      RU  53.6039   91.3903     -9.51        91          75
# 6   Carnarvon      AU -24.8667  113.6333    109.47         5           4
# 7  Georgetown      MY   5.4112  100.3354     82.33        81          20
# 8  Port Hardy      CA  50.6996 -127.4199     39.76       100          75
# 9    Vanavara      RU  60.3400  102.2797    -12.82       100         100
#
#    Wind Speed Current Description
# 0        9.48    scattered clouds
# 1        7.70          few clouds
# 2       10.11     overcast clouds
# 3        6.13    scattered clouds
# 4       11.50     overcast clouds
# 5        0.00                mist
# 6       17.27           clear sky
# 7        3.44          few clouds
# 8        3.44       broken clouds
# 9        1.59     overcast clouds

# %%
# Replace 'NA' country code to 'Namibia' to avoid NaN error later when working with CSV
city_data_df["Country"] = city_data_df["Country"].str.replace("NA","Namibia")
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Bluff      NZ -46.6000  168.3333     59.81        61          45
# 1     Mataura      NZ -46.1927  168.8643     59.49        40          11
# 2     Rikitea      PF -23.1203 -134.9692     78.76        71         100
# 3    Hermanus      ZA -34.4187   19.2345     84.90        62          49
# 4   Jamestown      US  42.0970  -79.2353     22.71        63         100
# 5   Belyy Yar      RU  53.6039   91.3903     -9.51        91          75
# 6   Carnarvon      AU -24.8667  113.6333    109.47         5           4
# 7  Georgetown      MY   5.4112  100.3354     82.33        81          20
# 8  Port Hardy      CA  50.6996 -127.4199     39.76       100          75
# 9    Vanavara      RU  60.3400  102.2797    -12.82       100         100
#
#    Wind Speed Current Description
# 0        9.48    scattered clouds
# 1        7.70          few clouds
# 2       10.11     overcast clouds
# 3        6.13    scattered clouds
# 4       11.50     overcast clouds
# 5        0.00                mist
# 6       17.27           clear sky
# 7        3.44          few clouds
# 8        3.44       broken clouds
# 9        1.59     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
